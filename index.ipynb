# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import sqlite3 
import pandas as pd
conn = sqlite3.Connection('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
#Your code here
cur.execute("""select firstName, lastName from employees e join offices o on e.officeCode = o.officeCode where city = 'Boston';""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#   firstName   lastName
# 0     Julie   Firrelli
# 1     Steve  Patterson

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here
cur.execute("""select city, count(*) 
from offices
join employees 
using(officeCode) 
group by city""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#             city  count(*)
# 0         Boston         2
# 1         London         2
# 2            NYC         2
# 3          Paris         5
# 4  San Francisco         6
# 5         Sydney         4
# 6          Tokyo         2

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here
cur.execute("""select firstName, lastName, productName
from employees e
join
customers c
on e.employee
join orderdetails o on p.productCode = o.productCode
group by p.productName
order by p.productVendor;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#                  productVendor                                productName  \
# 0        Autoart Studio Design                     1900s Vintage Bi-Plane
# 1        Autoart Studio Design                  1932 Model A Ford J-Coupe
# 2        Autoart Studio Design                  1937 Horch 930V Limousine
# 3        Autoart Studio Design                   1962 Volkswagen Microbus
# 4        Autoart Studio Design                          1968 Ford Mustang
# 5        Autoart Studio Design                          1997 BMW R 1100 S
# 6        Autoart Studio Design                         2002 Yamaha YZR M1
# 7        Autoart Studio Design                      The Schooner Bluenose
# 8     Carousel DieCast Legends                      18th century schooner
# 9     Carousel DieCast Legends                1913 Ford Model T Speedster
# 10    Carousel DieCast Legends                      1926 Ford Fire Engine
# 11    Carousel DieCast Legends                   1940 Ford Delivery Sedan
# 12    Carousel DieCast Legends        1958 Chevy Corvette Limited Edition
# 13    Carousel DieCast Legends                  1966 Shelby Cobra 427 S/C
# 14    Carousel DieCast Legends                            1982 Camaro Z28
# 15    Carousel DieCast Legends                   Collectable Wooden Train
# 16    Carousel DieCast Legends                                The Titanic
# 17     Classic Metal Creations           1928 British Royal Navy Airplane
# 18     Classic Metal Creations  1938 Cadillac V-16 Presidential Limousine
# 19     Classic Metal Creations                         1949 Jaguar XK 120
# 20     Classic Metal Creations                   1952 Alpine Renault 1300
# 21     Classic Metal Creations                1954 Greyhound Scenicruiser
# 22     Classic Metal Creations                    1956 Porsche 356A Coupe
# 23     Classic Metal Creations                  1957 Corvette Convertible
# 24     Classic Metal Creations                      1961 Chevrolet Impala
# 25     Classic Metal Creations             1962 City of Detroit Streetcar
# 26     Classic Metal Creations                      1965 Aston Martin DB5
# 27               Exoto Designs                        1904 Buick Runabout
# 28               Exoto Designs                   1917 Maxwell Touring Car
# 29               Exoto Designs        1932 Alfa Romeo 8C2300 Spider Sport
# ..                         ...                                        ...
# 79         Second Gear Diecast                           1969 Ford Falcon
# 80         Second Gear Diecast                  1974 Ducati 350 Mk3 Desmo
# 81         Second Gear Diecast                    1982 Lamborghini Diablo
# 82         Second Gear Diecast                          2001 Ferrari Enzo
# 83         Second Gear Diecast                  American Airlines: MD-11S
# 84         Second Gear Diecast                   Corsair F4U ( Bird Cage)
# 85         Studio M Art Models               1930 Buick Marquette Phaeton
# 86         Studio M Art Models   1936 Mercedes-Benz 500K Special Roadster
# 87         Studio M Art Models                    1939 Cadillac Limousine
# 88         Studio M Art Models                     1940 Ford Pickup Truck
# 89         Studio M Art Models                      1957 Ford Thunderbird
# 90         Studio M Art Models                           1957 Vespa GS150
# 91         Studio M Art Models                    1970 Plymouth Hemi Cuda
# 92         Studio M Art Models                              The Mayflower
# 93        Unimax Art Galleries                    1900s Vintage Tri-Plane
# 94        Unimax Art Galleries                          1903 Ford Model A
# 95        Unimax Art Galleries                     1964 Mercedes Tour Bus
# 96        Unimax Art Galleries                 1970 Chevy Chevelle SS 454
# 97        Unimax Art Galleries                1992 Ferrari 360 Spider red
# 98        Unimax Art Galleries                           2002 Suzuki XREO
# 99        Unimax Art Galleries                                 HMS Bounty
# 100       Unimax Art Galleries                                 Pont Yacht
# 101  Welly Diecast Productions                   1917 Grand Touring Sedan
# 102  Welly Diecast Productions        1936 Harley Davidson El Knucklehead
# 103  Welly Diecast Productions                             1958 Setra Bus
# 104  Welly Diecast Productions                         1968 Dodge Charger
# 105  Welly Diecast Productions                         1969 Corvair Monza
# 106  Welly Diecast Productions                         1969 Dodge Charger
# 107  Welly Diecast Productions                  1971 Alpine Renault 1600s
# 108  Welly Diecast Productions                             The Queen Mary
#
#     productCode
# 0      S24_2841
# 1      S18_2325
# 2      S24_3420
# 3      S24_2300
# 4      S12_1099
# 5      S24_1578
# 6      S50_4713
# 7     S700_1138
# 8      S24_2011
# 9      S18_2949
# 10     S18_2432
# 11     S24_3816
# 12     S24_2840
# 13     S24_1628
# 14    S700_2824
# 15     S18_3259
# 16    S700_3505
# 17     S24_1785
# 18     S24_2022
# 19     S24_2766
# 20     S10_1949
# 21     S32_2509
# 22     S24_3856
# 23     S18_4721
# 24     S24_4620
# 25     S50_1514
# 26     S18_1589
# 27     S18_4522
# 28     S18_3320
# 29     S18_4409
# ..          ...
# 79     S12_3891
# 80     S32_4485
# 81     S24_2972
# 82     S12_1108
# 83    S700_4002
# 84     S24_3949
# 85     S50_1341
# 86     S18_1367
# 87     S18_4668
# 88     S18_1097
# 89     S18_4933
# 90     S18_3782
# 91     S12_3990
# 92    S700_1938
# 93     S24_4278
# 94     S18_3140
# 95     S18_2319
# 96     S24_1046
# 97     S18_3232
# 98     S12_2823
# 99    S700_2047
# 100    S72_3212
# 101    S18_1749
# 102    S18_2625
# 103    S12_1666
# 104    S12_3380
# 105    S12_3148
# 106    S12_4675
# 107    S24_3371
# 108   S700_3962
#
# [109 rows x 3 columns]

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
