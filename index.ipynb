# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import sqlite3 
import pandas as pd
conn = sqlite3.Connection('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
#Your code here
cur.execute("""select firstName, lastName from employees e join offices o on e.officeCode = o.officeCode;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#    firstName   lastName
# 0      Diane     Murphy
# 1       Mary  Patterson
# 2       Jeff   Firrelli
# 3    William  Patterson
# 4     Gerard     Bondur
# 5    Anthony        Bow
# 6     Leslie   Jennings
# 7     Leslie   Thompson
# 8      Julie   Firrelli
# 9      Steve  Patterson
# 10  Foon Yue      Tseng
# 11    George     Vanauf
# 12      Loui     Bondur
# 13    Gerard  Hernandez
# 14    Pamela   Castillo
# 15     Larry       Bott
# 16     Barry      Jones
# 17      Andy     Fixter
# 18     Peter      Marsh
# 19       Tom       King
# 20      Mami      Nishi
# 21   Yoshimi       Kato
# 22    Martin     Gerard

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here
cur.execute("""select * from employees join offices using(officeCode) group by officeCode""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#   employeeNumber   lastName firstName extension  \
# 0           1166   Thompson    Leslie     x4065
# 1           1216  Patterson     Steve     x4334
# 2           1323     Vanauf    George     x4102
# 3           1702     Gerard    Martin     x2312
# 4           1625       Kato   Yoshimi      x102
# 5           1619       King       Tom      x103
# 6           1504      Jones     Barry      x102
#
#                              email officeCode reportsTo   jobTitle  \
# 0   lthompson@classicmodelcars.com          1      1143  Sales Rep
# 1  spatterson@classicmodelcars.com          2      1143  Sales Rep
# 2     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 3     mgerard@classicmodelcars.com          4      1102  Sales Rep
# 4       ykato@classicmodelcars.com          5      1621  Sales Rep
# 5       tking@classicmodelcars.com          6      1088  Sales Rep
# 6      bjones@classicmodelcars.com          7      1102  Sales Rep
#
#             city             phone              addressLine1 addressLine2  \
# 0  San Francisco   +1 650 219 4782         100 Market Street    Suite 300
# 1         Boston   +1 215 837 0825          1550 Court Place    Suite 102
# 2            NYC   +1 212 555 3000      523 East 53rd Street      apt. 5A
# 3          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue     Floor #2
# 6         London  +44 20 7877 2041       25 Old Broad Street      Level 7
#
#         state    country postalCode territory
# 0          CA        USA      94080        NA
# 1          MA        USA      02107        NA
# 2          NY        USA      10022        NA
# 3                 France      75017      EMEA
# 4  Chiyoda-Ku      Japan   102-8578     Japan
# 5              Australia   NSW 2010      APAC
# 6                     UK   EC2N 1HN      EMEA

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here
cur.execute("""select p.productVendor, p.productName, p.productCode
from products p
join orderdetails o on p.productCode = o.productCode;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#                 productVendor                            productName  \
# 0             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 1             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 2             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 3             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 4             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 5             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 6             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 7             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 8             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 9             Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 10            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 11            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 12            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 13            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 14            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 15            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 16            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 17            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 18            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 19            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 20            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 21            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 22            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 23            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 24            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 25            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 26            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 27            Min Lin Diecast  1969 Harley Davidson Ultimate Chopper
# 28    Classic Metal Creations               1952 Alpine Renault 1300
# 29    Classic Metal Creations               1952 Alpine Renault 1300
# ...                       ...                                    ...
# 2966  Motor City Art Classics                       Boeing X-32A JSF
# 2967  Motor City Art Classics                       Boeing X-32A JSF
# 2968  Motor City Art Classics                       Boeing X-32A JSF
# 2969     Unimax Art Galleries                             Pont Yacht
# 2970     Unimax Art Galleries                             Pont Yacht
# 2971     Unimax Art Galleries                             Pont Yacht
# 2972     Unimax Art Galleries                             Pont Yacht
# 2973     Unimax Art Galleries                             Pont Yacht
# 2974     Unimax Art Galleries                             Pont Yacht
# 2975     Unimax Art Galleries                             Pont Yacht
# 2976     Unimax Art Galleries                             Pont Yacht
# 2977     Unimax Art Galleries                             Pont Yacht
# 2978     Unimax Art Galleries                             Pont Yacht
# 2979     Unimax Art Galleries                             Pont Yacht
# 2980     Unimax Art Galleries                             Pont Yacht
# 2981     Unimax Art Galleries                             Pont Yacht
# 2982     Unimax Art Galleries                             Pont Yacht
# 2983     Unimax Art Galleries                             Pont Yacht
# 2984     Unimax Art Galleries                             Pont Yacht
# 2985     Unimax Art Galleries                             Pont Yacht
# 2986     Unimax Art Galleries                             Pont Yacht
# 2987     Unimax Art Galleries                             Pont Yacht
# 2988     Unimax Art Galleries                             Pont Yacht
# 2989     Unimax Art Galleries                             Pont Yacht
# 2990     Unimax Art Galleries                             Pont Yacht
# 2991     Unimax Art Galleries                             Pont Yacht
# 2992     Unimax Art Galleries                             Pont Yacht
# 2993     Unimax Art Galleries                             Pont Yacht
# 2994     Unimax Art Galleries                             Pont Yacht
# 2995     Unimax Art Galleries                             Pont Yacht
#
#      productCode
# 0       S10_1678
# 1       S10_1678
# 2       S10_1678
# 3       S10_1678
# 4       S10_1678
# 5       S10_1678
# 6       S10_1678
# 7       S10_1678
# 8       S10_1678
# 9       S10_1678
# 10      S10_1678
# 11      S10_1678
# 12      S10_1678
# 13      S10_1678
# 14      S10_1678
# 15      S10_1678
# 16      S10_1678
# 17      S10_1678
# 18      S10_1678
# 19      S10_1678
# 20      S10_1678
# 21      S10_1678
# 22      S10_1678
# 23      S10_1678
# 24      S10_1678
# 25      S10_1678
# 26      S10_1678
# 27      S10_1678
# 28      S10_1949
# 29      S10_1949
# ...          ...
# 2966    S72_1253
# 2967    S72_1253
# 2968    S72_1253
# 2969    S72_3212
# 2970    S72_3212
# 2971    S72_3212
# 2972    S72_3212
# 2973    S72_3212
# 2974    S72_3212
# 2975    S72_3212
# 2976    S72_3212
# 2977    S72_3212
# 2978    S72_3212
# 2979    S72_3212
# 2980    S72_3212
# 2981    S72_3212
# 2982    S72_3212
# 2983    S72_3212
# 2984    S72_3212
# 2985    S72_3212
# 2986    S72_3212
# 2987    S72_3212
# 2988    S72_3212
# 2989    S72_3212
# 2990    S72_3212
# 2991    S72_3212
# 2992    S72_3212
# 2993    S72_3212
# 2994    S72_3212
# 2995    S72_3212
#
# [2996 rows x 3 columns]

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
